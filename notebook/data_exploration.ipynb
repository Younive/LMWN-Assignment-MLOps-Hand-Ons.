# %%
import pandas as pd

# %%
# inspect restaurant.parquet
restaurant_df = pd.read_parquet('../data/restaurant.parquet')
restaurant_df
# Out:
#      restaurant_id  index            latitude           longitude
# 0            r0000      0  13.844851141246949   100.3086836106867
# 1            r0001      1  13.781825896541061  100.84977532273388
# 2            r0002      2  13.883572268183674   100.3085459374542
# 3            r0003      3  14.066725452665281   100.7256760943531
# 4            r0004      4  13.961173933525883  100.39580661948798
# ...            ...    ...                 ...                 ...
# 9995         r9995   9995  13.976247403316105  100.74591691224845
# 9996         r9996   9996  13.839804492696432  100.58250115679854
# 9997         r9997   9997  13.830883556338277  100.81450723230107
# 9998         r9998   9998   13.85324887148126  100.84175080319135
# 9999         r9999   9999  13.971511660502783  100.67347740957862
#
# [10000 rows x 4 columns]

# %%
restaurant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   restaurant_id  10000 non-null  object
#  1   index          10000 non-null  int64
#  2   latitude       10000 non-null  object
#  3   longitude      10000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
# inspect user.small.parquet
user_small_df = pd.read_parquet('../data/user.small.parquet')
user_small_df
# Out:
#   user_id  feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  u00000   0.193018   1.235771   0.478129   0.056068   0.798870   0.942501
# 1  u00001   0.542445   0.061676  -0.172018   0.366714   0.690263   0.565948
# 2  u00002   0.501249   1.194607   0.750967  -0.078167   0.361179   0.124189
# 3  u00003   0.613723  -0.652035   1.161827   0.122698   0.828054  -0.296040
# 4  u00004   0.179650   0.166768   0.337015   0.594367   0.897039   0.858783
# 5  u00005   0.228406   0.716593   0.139256  -0.440974   0.200366   1.068810
# 6  u00006  -0.128297  -0.199155   0.275741  -0.555123  -0.288713   0.926624
# 7  u00007   0.471740  -0.251303   0.115246   0.121640   0.956058   0.622212
# 8  u00008   0.498419   0.546189   1.109766   0.612085   0.877777   0.690837
# 9  u00009   0.265751  -0.120573   0.709822   1.268249   0.303105   0.193732
#
#    feature_6  feature_7  feature_8  ...  feature_990  feature_991  \
# ...

# %%
request_df = pd.read_parquet('../perf_test/request.parquet')
request_df
# Out:
#      user_id   latitude   longitude  size  sort_dis  max_dis
# 0     u83153  14.068817  100.646536    50       0.0   5000.0
# 1     u45712  14.109562  100.698690    50       1.0   5000.0
# 2     u52829  13.727387  100.830825    50       1.0   5000.0
# 3     u11570  13.921809  100.468203    20       1.0   5000.0
# 4     u99991  13.804917  100.682749    50       NaN   5000.0
# ...      ...        ...         ...   ...       ...      ...
# 1995  u26540  13.924127  100.611641    50       0.0  10000.0
# 1996  u39495  13.710599  100.714934    50       NaN      NaN
# 1997  u62643  13.995389  100.403283    50       1.0   5000.0
# 1998  u07949  13.683828  100.343557    50       0.0   5000.0
# 1999  u40099  13.988415  100.432730    20       NaN  10000.0
#
# [2000 rows x 6 columns]
